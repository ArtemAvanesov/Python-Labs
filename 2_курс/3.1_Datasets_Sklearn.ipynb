# %%
from sklearn.utils.multiclass import unique_labels
import mglearn
import matplotlib.pyplot as plt
import pandas as pd
from pandas import plotting
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets.samples_generator import make_blobs

X,y = make_blobs(random_state = 42)

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))

mglearn.discrete_scatter(X[:,0], X[:,1], y)
plt.legend(["Класс_0","Класс_1","Класс_2"])
plt.xlabel("Первый признак")
plt.ylabel("Второй признак")
# Out:
# Количество сэмплов:  100
# Количество признаков:  2
# Количество классов:  3
# Text(0, 0.5, 'Второй признак')

# %%
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X = cancer['data']
y = cancer['target']

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))
# Out:
# Количество сэмплов:  569
# Количество признаков:  30
# Количество классов:  2

# %%
from sklearn.datasets import load_digits

digits = load_digits()
X = digits['data']
y = digits['target']

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))

fig,axes = plt.subplots(2,5, figsize = (10,5), subplot_kw = {'xticks':(), 'yticks':()})
for ax, img in zip (axes.ravel(), digits.images):
    ax.imshow(img)
# Out:
# Количество сэмплов:  1797
# Количество признаков:  64
# Количество классов:  10

# %%
from sklearn.datasets import make_moons

X,y = make_moons(n_samples=200, noise=0.05, random_state=0)

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))

mglearn.discrete_scatter(X[:,0], X[:,1], y)
plt.legend(["Класс_0","Класс_1","Класс_2"])
plt.xlabel("Первый признак")
plt.ylabel("Второй признак")
# Out:
# Количество сэмплов:  200
# Количество признаков:  2
# Количество классов:  2
# Text(0, 0.5, 'Второй признак')

# %%
X,y = mglearn.datasets.make_forge()

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))

mglearn.discrete_scatter(X[:,0], X[:,1], y)
plt.legend(["Класс_0","Класс_1","Класс_2"])
plt.xlabel("Первый признак")
plt.ylabel("Второй признак")
# Out:
# Количество сэмплов:  26
# Количество признаков:  2
# Количество классов:  2
# Text(0, 0.5, 'Второй признак')

# %%
from sklearn.datasets import fetch_lfw_people

people = fetch_lfw_people(min_faces_per_person=20, resize=0.7)

X = people['data']
y = people['target']

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))

fix,axes = plt.subplots(2,5, figsize=(15,8), subplot_kw={'xticks':(),'yticks':()})
for target, image, ax in zip(people.target, people.images, axes.ravel()):
    ax.imshow(image)
    ax.set_title(people.target_names[target])
# Out:
# Количество сэмплов:  3023
# Количество признаков:  5655
# Количество классов:  62

# %%
from sklearn.datasets import load_iris

iris_dataset = load_iris()

X = iris_dataset.data
y = iris_dataset.target

print("Количество сэмплов: ", len(X[:,0]))
print("Количество признаков: ", len(X[0]))
print("Количество классов: ", len(unique_labels(y)))

# %matplotlib inline
iris_dataframe = pd.DataFrame(X, columns=iris_dataset.feature_names)
grr = plotting.scatter_matrix(iris_dataframe, c=y, figsize=(15, 15), marker='o', hist_kwds={'bins': 20}, s=60, alpha=.8)
# Out:
# Количество сэмплов:  150
# Количество признаков:  4
# Количество классов:  3
